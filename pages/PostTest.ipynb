# %% [markdown]
# 1. Předvídatelnost náhody

# %%
import random

x = random.randint(1, 5)
y = 10
vysledek = x + y

# %% [markdown]
# 2. Práce se vstupem (Logika typů)

# %%
cislo = "10" 
cislo_2 = "50"
print(cislo + cislo_2)
# Out:
# 1050

# %% [markdown]
# 3. nevím název

# %%
data = [10, 50, 30]
m = len(data)
print(data[1])
# Out:
# 50

# %% [markdown]
# 4. Indexace a Median

# %%
body = [10, 20, 30]
celkem = 0
for b in body:
    celkem = celkem + b
print(celkem)
# Out:
# 60

# %%
tony = [60, 72, 60, 64, 60]
x = len(tony)
suma = 0
for i in range(x):
  suma = suma + tony[i]
prum = suma/x
print(x)
# Out:
# 5

# %%
import random
for i in range(3):
    x = random.randint(1, 10)
print(i)
# Out:
# 2

# %%
cisla = [5, 15, 10]
vysledek = 0
for c in cisla:
    if c > 8:
        vysledek = c
print(vysledek)
# Out:
# 10

# %%
hlasitost = 90
if hlasitost > 80 and hlasitost < 100:
    print("Optimalni")
else:
    print("Chyba")
# Out:
# Optimalni

# %%
seznam = [60, 62]
for i in range(len(seznam)):
    if seznam[i] == 60:
        print("Start")
    else:
        print("Konec")
# Out:
# Start
# Konec

# %%
hodnoty = [10, 20, 5]
x = hodnoty[0]
for idx in range(1, len(hodnoty)):
    if hodnoty[idx] > x:
        x = hodnoty[idx]
print(x - hodnoty[0])
# Out:
# 10
